# %% [markdown]
# **复习：**在前面我们已经学习了Pandas基础，第二章我们开始进入数据分析的业务部分，在第二章第一节的内容中，我们学习了**数据的清洗**，这一部分十分重要，只有数据变得相对干净，我们之后对数据的分析才可以更有力。而这一节，我们要做的是数据重构，数据重构依旧属于数据理解（准备）的范围。

# %% [markdown]
# #### 开始之前，导入numpy、pandas包和数据

# %%
# 导入基本库
import numpy as np
import pandas as pd

# %%
# 载入data文件中的:train-left-up.csv
df_left_up = pd.read_csv('data/train-left-up.csv')
df_left_up
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 434          435         0       1
# 435          436         1       1
# 436          437         0       3
# 437          438         1       2
# 438          439         0       1
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 434                          Silvey, Mr. William Baird
# 435                          Carter, Miss. Lucile Polk
# ...

# %% [markdown]
# # 2 第二章：数据重构

# %% [markdown]
# ### 2.4 数据的合并

# %% [markdown]
# #### 2.4.1 任务一：将data文件夹里面的所有数据都载入，观察数据的之间的关系

# %%
#写入代码
df_left_down = pd.read_csv('data/train-left-down.csv')
df_left_down
# Out:
#      PassengerId  Survived  Pclass  \
# 0            440         0       2
# 1            441         1       2
# 2            442         0       3
# 3            443         0       3
# 4            444         1       2
# ..           ...       ...     ...
# 447          887         0       2
# 448          888         1       1
# 449          889         0       3
# 450          890         1       1
# 451          891         0       3
#
#                                             Name
# 0         Kvillner, Mr. Johan Henrik Johannesson
# 1    Hart, Mrs. Benjamin (Esther Ada Bloomfield)
# 2                                Hampe, Mr. Leon
# 3                      Petterson, Mr. Johan Emil
# 4                      Reynaldo, Ms. Encarnacion
# ..                                           ...
# 447                        Montvila, Rev. Juozas
# 448                 Graham, Miss. Margaret Edith
# 449     Johnston, Miss. Catherine Helen "Carrie"
# ...

# %%
#写入代码
df_right_down = pd.read_csv('data/train-right-down.csv')
df_right_down
# Out:
#         Sex   Age  SibSp  Parch        Ticket    Fare Cabin Embarked
# 0      male  31.0      0      0    C.A. 18723  10.500   NaN        S
# 1    female  45.0      1      1  F.C.C. 13529  26.250   NaN        S
# 2      male  20.0      0      0        345769   9.500   NaN        S
# 3      male  25.0      1      0        347076   7.775   NaN        S
# 4    female  28.0      0      0        230434  13.000   NaN        S
# ..      ...   ...    ...    ...           ...     ...   ...      ...
# 447    male  27.0      0      0        211536  13.000   NaN        S
# 448  female  19.0      0      0        112053  30.000   B42        S
# 449  female   NaN      1      2    W./C. 6607  23.450   NaN        S
# 450    male  26.0      0      0        111369  30.000  C148        C
# 451    male  32.0      0      0        370376   7.750   NaN        Q
#
# [452 rows x 8 columns]

# %%
df_right_up = pd.read_csv('data/train-right-up.csv')
df_right_up
# Out:
#         Sex   Age  SibSp  Parch            Ticket      Fare        Cabin  \
# 0      male  22.0      1      0         A/5 21171    7.2500          NaN
# 1    female  38.0      1      0          PC 17599   71.2833          C85
# 2    female  26.0      0      0  STON/O2. 3101282    7.9250          NaN
# 3    female  35.0      1      0            113803   53.1000         C123
# 4      male  35.0      0      0            373450    8.0500          NaN
# ..      ...   ...    ...    ...               ...       ...          ...
# 434    male  50.0      1      0             13507   55.9000          E44
# 435  female  14.0      1      2            113760  120.0000      B96 B98
# 436  female  21.0      2      2        W./C. 6608   34.3750          NaN
# 437  female  24.0      2      3             29106   18.7500          NaN
# 438    male  64.0      1      4             19950  263.0000  C23 C25 C27
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ...

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 【提示】结合之前我们加载的train.csv数据，大致预测一下上面的数据是什么

# %% [markdown]
# 将原来的数据评价切成四份，＋上下左右四块

# %% [markdown]
# #### 2.4.2：任务二：使用concat方法：将数据train-left-up.csv和train-right-up.csv横向合并为一张表，并保存这张表为result_up

# %%
#写入代码
result_up = pd.concat([df_left_up, df_right_up], axis=1)
result_up
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 434          435         0       1
# 435          436         1       1
# 436          437         0       3
# 437          438         1       2
# 438          439         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 2.4.3 任务三：使用concat方法：将train-left-down和train-right-down横向合并为一张表，并保存这张表为result_down。然后将上边的result_up和result_down纵向合并为result。

# %%
#写入代码
result_down = pd.concat([df_left_down, df_right_down], axis=1)
result_down
# Out:
#      PassengerId  Survived  Pclass  \
# 0            440         0       2
# 1            441         1       2
# 2            442         0       3
# 3            443         0       3
# 4            444         1       2
# ..           ...       ...     ...
# 447          887         0       2
# 448          888         1       1
# 449          889         0       3
# 450          890         1       1
# 451          891         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0         Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0      0
# 1    Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.0      1      1
# 2                                Hampe, Mr. Leon    male  20.0      0      0
# 3                      Petterson, Mr. Johan Emil    male  25.0      1      0
# 4                      Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %%
result = pd.concat([result_up, result_down])
result
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 447          887         0       2
# 448          888         1       1
# 449          889         0       3
# 450          890         1       1
# 451          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### 2.4.4 任务四：使用DataFrame自带的方法join方法和append：完成任务二和任务三的任务

# %% [markdown]
# 任务为：
#
# 使用concat方法：将数据train-left-up.csv和train-right-up.csv横向合并为一张表，并保存这张表为result_up
#
#
# 使用concat方法：将train-left-down和train-right-down横向合并为一张表，并保存这张表为result_down。然后将上边的result_up和result_down纵向合并为result。

# %% [markdown]
# append()和join()的用法：
#
# append()是将另一个 DataFrame 附加到一个DataFrame 的末尾。它的工作原理类似于 concat() with axis=0
#
# join()用于在一列或多列上连接两个 DataFrame。这意味着您可以join()通过匹配一列或多列中的值来组合 DataFrame。join() 方法可以在一个 DataFrame 上使用，它以另一个 DataFrame 和连接类型（左、右、内、外）作为参数。

# %%
result_up = df_left_up.join(df_right_up, how='right')
result_down = df_left_down.join(df_right_down, how='right')
result = result_up.append(result_down)
result
# Out:
# /tmp/ipykernel_358/3361680252.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result_up.append(result_down)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 447          887         0       2
# 448          888         1       1
# 449          889         0       3
# 450          890         1       1
# 451          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# #### 2.4.5 任务五：使用Panads的merge方法和DataFrame的append方法：完成任务二和任务三的任务

# %% [markdown]
# 任务为：
#
# 使用concat方法：将数据train-left-up.csv和train-right-up.csv横向合并为一张表，并保存这张表为result_up
#
#
# 使用concat方法：将train-left-down和train-right-down横向合并为一张表，并保存这张表为result_down。然后将上边的result_up和result_down纵向合并为result。

# %%
#写入代码
result_up = pd.merge(df_left_up, df_right_up,left_index=True, right_index=True)
result_down = pd.merge(df_left_down,df_right_down,left_index=True,right_index=True)
result = result_up.append(result_down)
result
# Out:
# /tmp/ipykernel_358/3435782979.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result_up.append(result_down)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 447          887         0       2
# 448          888         1       1
# 449          889         0       3
# 450          890         1       1
# 451          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# 【思考】对比merge、join以及concat的方法的不同以及相同。思考一下在任务四和任务五的情况下，为什么都要求使用DataFrame的append方法，如何只要求使用merge或者join可不可以完成任务四和任务五呢？

# %% [markdown]
# merge和join都是横向合并，不能纵向合并所以需要append来进行纵向合并
#
# merge和join的区别：
#
# merged_df = pd.merge(df1, df2, on='key', how='outer')
# df_join = df1.join(df2, on='key', how='outer')
#
# - join()方法只能在一个 DataFrame 上使用。merge()函数可用于连接任意两个 DataFrame。
#
# - join()并且merge()在加入时可以有不同的默认行为。join()默认为“内部”连接，而merge()默认为“外部”连接。
#
# - join()并且merge()在连接具有不同索引的 DataFrame 时可以有不同的性能。当 DataFrame 具有不同的索引时join()通常更快，而当 DataFrame 具有相同的索引时merge()通常更快。
#
# 通常，join()当您想要通过匹配索引来组合 DataFrames 时可以使用，当您想要通过匹配一列或多列中的值来组合 DataFrames 时可以使用merge()。

# %% [markdown]
# #### 2.4.6 任务六：完成的数据保存为result.csv

# %%
#写入代码
result.to_csv('result.csv')

# %% [markdown]
# ### 2.5 换一种角度看数据

# %% [markdown]
# #### 2.5.1 任务一：将我们的数据变为Series类型的数据

# %%
#将数据的列都旋转为行
df_series = result.stack()
df_series
# Out:
# 0    PassengerId                          1
#      Survived                             0
#      Pclass                               3
#      Name           Braund, Mr. Owen Harris
#      Sex                               male
#                              ...
# 451  SibSp                                0
#      Parch                                0
#      Ticket                          370376
#      Fare                              7.75
#      Embarked                             Q
# Length: 9826, dtype: object

# %%
df_series.head()
# Out:
# 0  PassengerId                          1
#    Survived                             0
#    Pclass                               3
#    Name           Braund, Mr. Owen Harris
#    Sex                               male
# dtype: object
